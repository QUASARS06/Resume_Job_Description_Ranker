# %%
import os
import fitz
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import math
pd.set_option('display.max_colwidth', None)

# %%
def print_full_jd(jd_titles, jd_texts, jd_id):
    if jd_id >= len(jd_titles):
        print(f"JD ID {jd_id} out of range.")
        return
    print(f"\n=== JD ID {jd_id} ===")
    print(f"Job Title: {jd_titles[jd_id]}")
    print(f"Description:\n{jd_texts[jd_id]}")

# %%
def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        with fitz.open(pdf_path) as doc:
            for page in doc:
                text += page.get_text()
    except Exception as e:
        print(f"Error reading {pdf_path}: {e}")
    return text

# %%
def read_resumes(base_dir, categories):
    texts = []
    names = []
    for category in categories:
        folder = os.path.join(base_dir, category)
        for fname in os.listdir(folder):
            if fname.endswith(".pdf"):
                full_path = os.path.join(folder, fname)
                text = extract_text_from_pdf(full_path)
                texts.append(text)
                names.append(fname)
    return names, texts

# %%
def read_job_descriptions(csv_path):
    df = pd.read_csv(csv_path)
    jd_texts = df['Job Description'].astype(str).tolist()
    jd_titles = df['Job Title'].astype(str).tolist()
    return jd_titles, jd_texts

# %%
def match_resumes_tfidf_cosine(resume_names, resume_texts, jd_titles, jd_texts, top_k=10):
    all_docs = resume_texts + jd_texts
    vectorizer = TfidfVectorizer(stop_words='english')
    tfidf_matrix = vectorizer.fit_transform(all_docs)

    resume_vecs = tfidf_matrix[:len(resume_texts)]
    jd_vecs = tfidf_matrix[len(resume_texts):]

    sim_matrix = cosine_similarity(resume_vecs, jd_vecs)

    results = {}
    for i, resume_name in enumerate(resume_names):
        top_matches = sorted(
            list(enumerate(sim_matrix[i])), key=lambda x: -x[1]
        )[:top_k]
        results[resume_name] = [(idx, score, jd_titles[idx]) for idx, score in top_matches]
    return results, vectorizer, jd_texts

# %%
def show_top_tokens_for_match(resume_text, jd_text, vectorizer, top_n=20):
    tfidf = vectorizer.transform([resume_text, jd_text])
    feature_names = vectorizer.get_feature_names_out()
    
    r_vec = tfidf[0].toarray()[0]
    jd_vec = tfidf[1].toarray()[0]
    common_indices = (r_vec > 0) & (jd_vec > 0)
    importance = r_vec * jd_vec  # element-wise

    scored_tokens = [(feature_names[i], importance[i]) for i in range(len(importance)) if common_indices[i]]
    top_tokens = sorted(scored_tokens, key=lambda x: -x[1])[:top_n]

    print("\nTop Overlapping Tokens by TF-IDF Score:")
    for token, score in top_tokens:
        print(f"- {token}: {score:.4f}")

# %%
categories = ['INFORMATION-TECHNOLOGY']
base_resume_dir = './resume_pds/data/data'
jd_csv_path = 'job_title_des.csv'

# %%
resume_names, resume_texts = read_resumes(base_resume_dir, categories)
jd_titles, jd_texts = read_job_descriptions(jd_csv_path)

# %%
print(len(jd_titles), len(resume_names))
# Out:
# 2277 120

# %%
results, vectorizer, all_jd_texts = match_resumes_tfidf_cosine(
    resume_names, resume_texts, jd_titles, jd_texts, top_k=5
)

# %%
results
# Out:
# {'18176523.pdf': [(580,
#    np.float64(0.2593151513793338),
#    'Network Administrator'),
#   (1655, np.float64(0.23153351455868848), 'Network Administrator'),
#   (399, np.float64(0.22670050939708306), 'Network Administrator'),
#   (1459, np.float64(0.21557553551490205), 'Database Administrator'),
#   (530, np.float64(0.20662352413453444), 'Network Administrator')],
#  '25857360.pdf': [(420,
#    np.float64(0.19220159704518303),
#    'Database Administrator'),
#   (2033, np.float64(0.16027720773733667), 'Database Administrator'),
#   (534, np.float64(0.1404553674648251), 'Database Administrator'),
#   (102, np.float64(0.13623401202449956), 'Node js developer'),
#   (2169, np.float64(0.1269059853711599), 'Database Administrator')],
#  '39718499.pdf': [(2172,
#    np.float64(0.10647038931026832),
#    'Database Administrator'),
#   (847, np.float64(0.09471837140949621), 'Software Engineer'),
#   (1245, np.float64(0.08254224213650725), 'Backend Developer'),
#   (1409, np.float64(0.08189912088968837), 'Full Stack Developer'),
#   (2169, np.float64(0.08145124367406097), 'Database Administrator')],
#  '40018190.pdf': [(1888,
#    np.float64(0.19997560343491402),
#    'Database Administrator'),
#   (1076, np.float64(0.18474639363025613), 'Network Administrator'),
#   (2163, np.float64(0.17720035549872346), 'Network Administrator'),
#   (2137, np.float64(0.1734683737456226), 'Network Administrator'),
#   (23, np.float64(0.17208104356863463), 'Database Administrator')],
#  '31243710.pdf': [(903,
#    np.float64(0.33379656385340517),
#    'Network Administrator'),
#   (1362, np.float64(0.30602231583671985), 'Network Administrator'),
#   (595, np.float64(0.3056183946102431), 'Network Administrator'),
#   (580, np.float64(0.29298517643368716), 'Network Administrator'),
#   (1816, np.float64(0.270831153453864), 'Network Administrator')],
#  '25990239.pdf': [(1888,
#    np.float64(0.21310802384643107),
#    'Database Administrator'),
#   (23, np.float64(0.17862792051258897), 'Database Administrator'),
#   (625, np.float64(0.17683249449556468), 'Database Administrator'),
#   (1401, np.float64(0.17628908726852027), 'Java Developer'),
#   (1770, np.float64(0.16490778936982828), 'Machine Learning')],
#  '52246737.pdf': [(1071,
#    np.float64(0.25032821938573185),
#    'Database Administrator'),
#   (1655, np.float64(0.21692383896424736), 'Network Administrator'),
#   (1323, np.float64(0.2008254908273417), 'Network Administrator'),
#   (1271, np.float64(0.1953592715686488), 'Database Administrator'),
#   (2142, np.float64(0.1901155005991823), 'Network Administrator')],
#  '19201175.pdf': [(580,
#    np.float64(0.15283735422660172),
#    'Network Administrator'),
#   (589, np.float64(0.14749911934493887), 'Network Administrator'),
#   (595, np.float64(0.14672192491714056), 'Network Administrator'),
#   (530, np.float64(0.14414294020226692), 'Network Administrator'),
#   (1655, np.float64(0.14362119097616688), 'Network Administrator')],
#  '36434348.pdf': [(1348,
#    np.float64(0.26963861706589365),
#    'Database Administrator'),
#   (1938, np.float64(0.24775602961397541), 'Database Administrator'),
#   (1013, np.float64(0.22788076573136953), 'Database Administrator'),
#   (18, np.float64(0.21944771106105712), 'Database Administrator'),
#   (1655, np.float64(0.21821175734527384), 'Network Administrator')],
#  '25207620.pdf': [(580,
#    np.float64(0.21158613080684652),
#    'Network Administrator'),
#   (2137, np.float64(0.20449186122921456), 'Network Administrator'),
#   (1775, np.float64(0.20211976188859657), 'Database Administrator'),
#   (399, np.float64(0.19331271410857817), 'Network Administrator'),
#   (1385, np.float64(0.19018542645211572), 'Network Administrator')],
#  '12635195.pdf': [(23,
#    np.float64(0.15808467504936072),
#    'Database Administrator'),
#   (802, np.float64(0.1538042214489012), 'Software Engineer'),
#   (2089, np.float64(0.1510957746511846), 'Database Administrator'),
#   (2104, np.float64(0.1471593779245005), 'Database Administrator'),
#   (2137, np.float64(0.14555150288609964), 'Network Administrator')],
#  '26746496.pdf': [(2105, np.float64(0.3499096882404066), 'Backend Developer'),
#   (2017, np.float64(0.2519334714199269), 'Java Developer'),
#   (373, np.float64(0.2491624048311112), 'Software Engineer'),
#   (1944, np.float64(0.23890672844441166), 'Network Administrator'),
#   (1403, np.float64(0.21816590743007286), 'Java Developer')],
#  '23666211.pdf': [(1127, np.float64(0.15345603626996981), 'PHP Developer'),
#   (1413, np.float64(0.14414413489827888), 'Database Administrator'),
#   (10, np.float64(0.14299646544971248), 'Database Administrator'),
#   (23, np.float64(0.14274698290776106), 'Database Administrator'),
#   (1770, np.float64(0.14186492706730613), 'Machine Learning')],
#  '24038620.pdf': [(1850,
#    np.float64(0.189527387229561),
#    'Network Administrator'),
#   (1655, np.float64(0.18790241257820348), 'Network Administrator'),
#   (947, np.float64(0.18548962703449914), 'Java Developer'),
#   (580, np.float64(0.17422736273693673), 'Network Administrator'),
#   (559, np.float64(0.17107978978125218), 'Network Administrator')],
#  '29051656.pdf': [(1201,
#    np.float64(0.3426469400331859),
#    'Database Administrator'),
#   (18, np.float64(0.3021504917644638), 'Database Administrator'),
#   (728, np.float64(0.27720889510226765), 'Database Administrator'),
#   (1730, np.float64(0.23931129569455634), 'Database Administrator'),
#   (2205, np.float64(0.2289974672377959), 'Database Administrator')],
#  '33381211.pdf': [(1480, np.float64(0.16365833151861464), 'DevOps Engineer'),
#   (2228, np.float64(0.16361409343937336), 'Network Administrator'),
#   (267, np.float64(0.16227853005516343), 'DevOps Engineer'),
#   (1707, np.float64(0.15663167544398598), 'JavaScript Developer'),
#   (2092, np.float64(0.15120610969265058), 'DevOps Engineer')],
#  '10840430.pdf': [(1655,
#    np.float64(0.23731858793642027),
#    'Network Administrator'),
#   (589, np.float64(0.1924310304563616), 'Network Administrator'),
#   (2163, np.float64(0.18410295192526827), 'Network Administrator'),
#   (530, np.float64(0.1833827197070965), 'Network Administrator'),
#   (1076, np.float64(0.17556597673705734), 'Network Administrator')],
#  '28697203.pdf': [(320,
#    np.float64(0.2749570303816176),
#    'Network Administrator'),
#   (2244, np.float64(0.22844549769042874), 'Backend Developer'),
#   (599, np.float64(0.22565296315405461), 'Software Engineer'),
#   (893, np.float64(0.22261297890154302), 'Software Engineer'),
#   (356, np.float64(0.20793807374264484), 'Software Engineer')],
#  '38753827.pdf': [(580,
#    np.float64(0.32260489964732625),
#    'Network Administrator'),
#   (399, np.float64(0.28145497505083594), 'Network Administrator'),
#   (903, np.float64(0.27905121573163877), 'Network Administrator'),
#   (595, np.float64(0.23555215047677883), 'Network Administrator'),
#   (134, np.float64(0.23453685988348888), 'Network Administrator')],
#  '27372171.pdf': [(580,
#    np.float64(0.2907237518800542),
#    'Network Administrator'),
#   (1655, np.float64(0.2813016003346398), 'Network Administrator'),
#   (1346, np.float64(0.25752321774003356), 'Network Administrator'),
#   (1362, np.float64(0.2497787502402775), 'Network Administrator'),
#   (399, np.float64(0.24765582628533084), 'Network Administrator')],
#  '24889109.pdf': [(580,
#    np.float64(0.182197621508121),
#    'Network Administrator'),
#   (823, np.float64(0.17019823297319409), 'Network Administrator'),
#   (399, np.float64(0.1557421916490603), 'Network Administrator'),
#   (1655, np.float64(0.15406904974028507), 'Network Administrator'),
#   (595, np.float64(0.15013055339029333), 'Network Administrator')],
#  '15802627.pdf': [(580,
#    np.float64(0.24557608836699066),
#    'Network Administrator'),
#   (1346, np.float64(0.2293644387643122), 'Network Administrator'),
#   (1076, np.float64(0.22494843066972653), 'Network Administrator'),
#   (1283, np.float64(0.2194701988750121), 'Network Administrator'),
#   (595, np.float64(0.21624492628057554), 'Network Administrator')],
#  '41344156.pdf': [(947, np.float64(0.1799910207354542), 'Java Developer'),
#   (1271, np.float64(0.15679660923101119), 'Database Administrator'),
#   (1971, np.float64(0.1561688431494571), 'Network Administrator'),
#   (2105, np.float64(0.15224310410896835), 'Backend Developer'),
#   (1348, np.float64(0.15039996412936701), 'Database Administrator')],
#  '21283365.pdf': [(1459,
#    np.float64(0.2213167282871661),
#    'Database Administrator'),
#   (1655, np.float64(0.19853895105110397), 'Network Administrator'),
#   (364, np.float64(0.19474869119387772), 'Network Administrator'),
#   (2228, np.float64(0.19072795518441882), 'Network Administrator'),
#   (1076, np.float64(0.18998328572170842), 'Network Administrator')],
#  '19796840.pdf': [(674,
#    np.float64(0.3069232943731197),
#    'Database Administrator'),
#   (1846, np.float64(0.20247557469591526), 'Database Administrator'),
#   (1655, np.float64(0.19977888387628226), 'Network Administrator'),
#   (1583, np.float64(0.1993015571514908), 'Java Developer'),
#   (1956, np.float64(0.19068009129913738), 'Node js developer')],
#  '20001721.pdf': [(1888,
#    np.float64(0.25443137292077983),
#    'Database Administrator'),
#   (2089, np.float64(0.18838113831543307), 'Database Administrator'),
#   (86, np.float64(0.17901385401205738), 'Database Administrator'),
#   (1013, np.float64(0.14616768879377703), 'Database Administrator'),
#   (1991, np.float64(0.1453797585231244), 'Software Engineer')],
#  '10247517.pdf': [(580,
#    np.float64(0.26227595047946084),
#    'Network Administrator'),
#   (1076, np.float64(0.2485373636616026), 'Network Administrator'),
#   (1528, np.float64(0.23020848888333376), 'Network Administrator'),
#   (399, np.float64(0.22931655295267675), 'Network Administrator'),
#   (1813, np.float64(0.2211707543141708), 'Network Administrator')],
#  '13385306.pdf': [(2105, np.float64(0.2745760104986604), 'Backend Developer'),
#   (1348, np.float64(0.24554885204090043), 'Database Administrator'),
#   (1938, np.float64(0.23586977917744653), 'Database Administrator'),
#   (947, np.float64(0.23227642404717355), 'Java Developer'),
#   (1944, np.float64(0.21563145702698605), 'Network Administrator')],
#  '20674668.pdf': [(1425, np.float64(0.35344951825535176), 'PHP Developer'),
#   (302, np.float64(0.2267590815890297), 'Full Stack Developer'),
#   (2236, np.float64(0.16371854291348398), 'PHP Developer'),
#   (2145, np.float64(0.16321427919904322), 'PHP Developer'),
#   (515, np.float64(0.1565562331257008), 'Java Developer')],
#  '24230851.pdf': [(568,
#    np.float64(0.20752666760574784),
#    'Database Administrator'),
#   (336, np.float64(0.14935118573155357), 'Software Engineer'),
#   (1459, np.float64(0.1411887734845096), 'Database Administrator'),
#   (515, np.float64(0.13594744703667763), 'Java Developer'),
#   (736, np.float64(0.13380692254981758), 'Full Stack Developer')],
#  '33241454.pdf': [(580,
#    np.float64(0.18409013475046904),
#    'Network Administrator'),
#   (324, np.float64(0.1742897435168477), 'Network Administrator'),
#   (427, np.float64(0.15866478052294064), 'Network Administrator'),
#   (1009, np.float64(0.15826309507401076), 'Network Administrator'),
#   (2144, np.float64(0.15253635632015516), 'Database Administrator')],
#  '22450718.pdf': [(1655,
#    np.float64(0.2631214345066607),
#    'Network Administrator'),
#   (1076, np.float64(0.2472261408512604), 'Network Administrator'),
#   (530, np.float64(0.21603144970702678), 'Network Administrator'),
#   (626, np.float64(0.21585053142164798), 'Database Administrator'),
#   (580, np.float64(0.21389995953025953), 'Network Administrator')],
#  '26768723.pdf': [(1888,
#    np.float64(0.19833079366201276),
#    'Database Administrator'),
#   (580, np.float64(0.19449619452455533), 'Network Administrator'),
#   (1009, np.float64(0.18235566644499163), 'Network Administrator'),
#   (669, np.float64(0.1784543744189971), 'Network Administrator'),
#   (1362, np.float64(0.17582124094631638), 'Network Administrator')],
#  '35325329.pdf': [(1846,
#    np.float64(0.2167258299458186),
#    'Database Administrator'),
#   (320, np.float64(0.20008516504427987), 'Network Administrator'),
#   (599, np.float64(0.1721152964530814), 'Software Engineer'),
#   (2244, np.float64(0.16368910480785234), 'Backend Developer'),
#   (625, np.float64(0.1622600178920148), 'Database Administrator')],
#  '39413067.pdf': [(580,
#    np.float64(0.34554955437918405),
#    'Network Administrator'),
#   (1076, np.float64(0.2981422066666731), 'Network Administrator'),
#   (1009, np.float64(0.2761529484334836), 'Network Administrator'),
#   (399, np.float64(0.27383460298720663), 'Network Administrator'),
#   (1362, np.float64(0.2692253616114449), 'Network Administrator')],
#  '12334140.pdf': [(1666, np.float64(0.15420390071497306), 'Django Developer'),
#   (890, np.float64(0.13549688809982333), 'Machine Learning'),
#   (1095, np.float64(0.13326370314870664), 'DevOps Engineer'),
#   (563, np.float64(0.13295941522035168), 'Full Stack Developer'),
#   (702, np.float64(0.1324697313521863), 'Full Stack Developer')],
#  '12045067.pdf': [(1655,
#    np.float64(0.16449214741981424),
#    'Network Administrator'),
#   (595, np.float64(0.16012130542579925), 'Network Administrator'),
#   (893, np.float64(0.1445148102699478), 'Software Engineer'),
#   (580, np.float64(0.14322437078678138), 'Network Administrator'),
#   (530, np.float64(0.13491221468085632), 'Network Administrator')],
#  '83816738.pdf': [(1316, np.float64(0.24407762961125803), 'Java Developer'),
#   (396, np.float64(0.2431018138138136), 'Java Developer'),
#   (560, np.float64(0.23184709031037296), 'Java Developer'),
#   (2244, np.float64(0.22874560151668097), 'Backend Developer'),
#   (607, np.float64(0.22290954050675246), 'Software Engineer')],
#  '27295996.pdf': [(1346,
#    np.float64(0.28918582616724936),
#    'Network Administrator'),
#   (580, np.float64(0.2781739897178717), 'Network Administrator'),
#   (1076, np.float64(0.2620146478940939), 'Network Administrator'),
#   (427, np.float64(0.2554407567980151), 'Network Administrator'),
#   (399, np.float64(0.25133579982314025), 'Network Administrator')],
#  '28035460.pdf': [(1655,
#    np.float64(0.16706520793369),
#    'Network Administrator'),
#   (1076, np.float64(0.159576841290654), 'Network Administrator'),
#   (625, np.float64(0.15882967394458197), 'Database Administrator'),
#   (1271, np.float64(0.15651690031959514), 'Database Administrator'),
#   (23, np.float64(0.15099831813632214), 'Database Administrator')],
#  '81761658.pdf': [(1362,
#    np.float64(0.2974591874636267),
#    'Network Administrator'),
#   (1655, np.float64(0.2585114475459201), 'Network Administrator'),
#   (1071, np.float64(0.24227163008641817), 'Database Administrator'),
#   (580, np.float64(0.23484573372907225), 'Network Administrator'),
#   (1850, np.float64(0.23441729717533127), 'Network Administrator')],
#  '23527321.pdf': [(1692,
#    np.float64(0.2569460768918128),
#    'JavaScript Developer'),
#   (2224, np.float64(0.2558834855715271), 'JavaScript Developer'),
#   (2128, np.float64(0.2548272176947972), 'JavaScript Developer'),
#   (1008, np.float64(0.2537861617917251), 'JavaScript Developer'),
#   (1477, np.float64(0.25090116404801094), 'JavaScript Developer')],
#  '10641230.pdf': [(881,
#    np.float64(0.1959815621711104),
#    'Network Administrator'),
#   (399, np.float64(0.19158840149983045), 'Network Administrator'),
#   (1204, np.float64(0.19139946278665046), 'Network Administrator'),
#   (823, np.float64(0.18762482288136637), 'Network Administrator'),
#   (530, np.float64(0.18501080516922358), 'Network Administrator')],
#  '17681064.pdf': [(823,
#    np.float64(0.16519659561841343),
#    'Network Administrator'),
#   (947, np.float64(0.15849430399190007), 'Java Developer'),
#   (637, np.float64(0.15729396081111588), 'Database Administrator'),
#   (1724, np.float64(0.15724407992209632), 'Machine Learning'),
#   (2228, np.float64(0.15718655354601796), 'Network Administrator')],
#  '27770859.pdf': [(580,
#    np.float64(0.19676516773422378),
#    'Network Administrator'),
#   (881, np.float64(0.18953278729303147), 'Network Administrator'),
#   (1204, np.float64(0.18399348135961083), 'Network Administrator'),
#   (1385, np.float64(0.17931939644160638), 'Network Administrator'),
#   (1594, np.float64(0.1760183604108516), 'Network Administrator')],
#  '51639418.pdf': [(1348,
#    np.float64(0.16472090773802706),
#    'Database Administrator'),
#   (625, np.float64(0.1577980995234077), 'Database Administrator'),
#   (1655, np.float64(0.15601735283641363), 'Network Administrator'),
#   (580, np.float64(0.1497180371387998), 'Network Administrator'),
#   (2069, np.float64(0.14099349544875522), 'Database Administrator')],
#  '11584809.pdf': [(580,
#    np.float64(0.300619375492911),
#    'Network Administrator'),
#   (1816, np.float64(0.2864391240351705), 'Network Administrator'),
#   (1283, np.float64(0.26840080230467356), 'Network Administrator'),
#   (1076, np.float64(0.2662800314792929), 'Network Administrator'),
#   (595, np.float64(0.263764767665142), 'Network Administrator')],
#  '27058381.pdf': [(530,
#    np.float64(0.1527612597584798),
#    'Network Administrator'),
#   (399, np.float64(0.13637515439085326), 'Network Administrator'),
#   (580, np.float64(0.13576345256826455), 'Network Administrator'),
#   (1839, np.float64(0.1343421591767872), 'Network Administrator'),
#   (823, np.float64(0.13290299833167513), 'Network Administrator')],
#  '37764298.pdf': [(1009,
#    np.float64(0.18087978493803225),
#    'Network Administrator'),
#   (1888, np.float64(0.17552248882245838), 'Database Administrator'),
#   (2137, np.float64(0.17296108066813154), 'Network Administrator'),
#   (399, np.float64(0.1705624501098775), 'Network Administrator'),
#   (2089, np.float64(0.15720512423551714), 'Database Administrator')],
#  '15297298.pdf': [(1816,
#    np.float64(0.1762826854960283),
#    'Network Administrator'),
#   (1315, np.float64(0.16611458615264543), 'Database Administrator'),
#   (580, np.float64(0.16075350470555227), 'Network Administrator'),
#   (1655, np.float64(0.15904122531850806), 'Network Administrator'),
#   (1850, np.float64(0.1547045640789578), 'Network Administrator')],
#  '25959103.pdf': [(580,
#    np.float64(0.29653889980986425),
#    'Network Administrator'),
#   (131, np.float64(0.28016549064290985), 'Network Administrator'),
#   (595, np.float64(0.2649101237393327), 'Network Administrator'),
#   (1076, np.float64(0.26300933260155085), 'Network Administrator'),
#   (1655, np.float64(0.23870889653220032), 'Network Administrator')],
#  '46260230.pdf': [(2163,
#    np.float64(0.2883392213980114),
#    'Network Administrator'),
#   (1076, np.float64(0.2816562156526754), 'Network Administrator'),
#   (580, np.float64(0.2799320711544138), 'Network Administrator'),
#   (669, np.float64(0.27671596281139427), 'Network Administrator'),
#   (2137, np.float64(0.2682355005053235), 'Network Administrator')],
#  '27485716.pdf': [(13, np.float64(0.21102591892788397), 'Software Engineer'),
#   (1655, np.float64(0.2026297517685495), 'Network Administrator'),
#   (947, np.float64(0.19811954077958352), 'Java Developer'),
#   (1071, np.float64(0.1940202739806154), 'Database Administrator'),
#   (580, np.float64(0.19290382984790028), 'Network Administrator')],
#  '16899268.pdf': [(734, np.float64(0.15400677168483434), 'Backend Developer'),
#   (2177, np.float64(0.1508073374909237), 'Java Developer'),
#   (13, np.float64(0.14930515576189027), 'Software Engineer'),
#   (1401, np.float64(0.14236659648359523), 'Java Developer'),
#   (336, np.float64(0.1405389594069886), 'Software Engineer')],
#  '18301617.pdf': [(1655,
#    np.float64(0.2549159146755552),
#    'Network Administrator'),
#   (580, np.float64(0.25453874566643825), 'Network Administrator'),
#   (1076, np.float64(0.25422523225236615), 'Network Administrator'),
#   (2163, np.float64(0.23207799910441335), 'Network Administrator'),
#   (1459, np.float64(0.2299050955514529), 'Database Administrator')],
#  '17987433.pdf': [(684,
#    np.float64(0.0764505667705192),
#    'Database Administrator'),
#   (490, np.float64(0.07003688117130022), 'Full Stack Developer'),
#   (310, np.float64(0.06968521269390948), 'Machine Learning'),
#   (1707, np.float64(0.06503555282769091), 'JavaScript Developer'),
#   (1435, np.float64(0.06431551453684715), 'Software Engineer')],
#  '26801767.pdf': [(1348,
#    np.float64(0.2071890402191178),
#    'Database Administrator'),
#   (1826, np.float64(0.2042242906916799), 'Database Administrator'),
#   (1655, np.float64(0.19233253420572266), 'Network Administrator'),
#   (1401, np.float64(0.1851855819085896), 'Java Developer'),
#   (23, np.float64(0.18030213235537207), 'Database Administrator')],
#  '16533554.pdf': [(580,
#    np.float64(0.30532321792839295),
#    'Network Administrator'),
#   (399, np.float64(0.2961071573752103), 'Network Administrator'),
#   (903, np.float64(0.2955131361061199), 'Network Administrator'),
#   (1362, np.float64(0.26337765595442275), 'Network Administrator'),
#   (1009, np.float64(0.25388964619104243), 'Network Administrator')],
#  '32959732.pdf': [(1888,
#    np.float64(0.23430896177962246),
#    'Database Administrator'),
#   (1459, np.float64(0.20843550121202042), 'Database Administrator'),
#   (23, np.float64(0.20774714193236493), 'Database Administrator'),
#   (1401, np.float64(0.18068199076101735), 'Java Developer'),
#   (2228, np.float64(0.17945561292884768), 'Network Administrator')],
#  '28126340.pdf': [(2105, np.float64(0.2570131108764018), 'Backend Developer'),
#   (947, np.float64(0.2441892618101035), 'Java Developer'),
#   (1938, np.float64(0.2317330972415278), 'Database Administrator'),
#   (1944, np.float64(0.21217078915281057), 'Network Administrator'),
#   (1348, np.float64(0.21208693960814812), 'Database Administrator')],
#  '15118506.pdf': [(1459,
#    np.float64(0.2212358939350506),
#    'Database Administrator'),
#   (941, np.float64(0.20699023917289855), 'JavaScript Developer'),
#   (138, np.float64(0.20666591914727725), 'JavaScript Developer'),
#   (1071, np.float64(0.1914814940386419), 'Database Administrator'),
#   (1504, np.float64(0.18196153250943997), 'Database Administrator')],
#  '89413122.pdf': [(1413,
#    np.float64(0.1612486191112729),
#    'Database Administrator'),
#   (947, np.float64(0.15988192390489683), 'Java Developer'),
#   (2069, np.float64(0.15556567808451893), 'Database Administrator'),
#   (244, np.float64(0.1521573041682852), 'Full Stack Developer'),
#   (625, np.float64(0.15070045524633569), 'Database Administrator')],
#  '64017585.pdf': [(580,
#    np.float64(0.17201903608054067),
#    'Network Administrator'),
#   (1346, np.float64(0.12989074486920912), 'Network Administrator'),
#   (1459, np.float64(0.12847493835706977), 'Database Administrator'),
#   (399, np.float64(0.1276504387780576), 'Network Administrator'),
#   (133, np.float64(0.1275984414718333), 'DevOps Engineer')],
#  '66832845.pdf': [(1362,
#    np.float64(0.28247328809232447),
#    'Network Administrator'),
#   (1385, np.float64(0.25891228063114624), 'Network Administrator'),
#   (580, np.float64(0.25427507369637947), 'Network Administrator'),
#   (1818, np.float64(0.24804705041489716), 'Network Administrator'),
#   (399, np.float64(0.22247001509387482), 'Network Administrator')],
#  '26480367.pdf': [(580,
#    np.float64(0.34134701799561673),
#    'Network Administrator'),
#   (2137, np.float64(0.3244369604305884), 'Network Administrator'),
#   (1076, np.float64(0.30133672161667624), 'Network Administrator'),
#   (669, np.float64(0.30065004570140863), 'Network Administrator'),
#   (1009, np.float64(0.2871291729568953), 'Network Administrator')],
#  '20408458.pdf': [(580,
#    np.float64(0.21409550905867253),
#    'Network Administrator'),
#   (1362, np.float64(0.20266732362396447), 'Network Administrator'),
#   (1009, np.float64(0.19475776590380753), 'Network Administrator'),
#   (399, np.float64(0.18380139447990157), 'Network Administrator'),
#   (131, np.float64(0.16917032714310215), 'Network Administrator')],
#  '24913648.pdf': [(580,
#    np.float64(0.36588821920006753),
#    'Network Administrator'),
#   (595, np.float64(0.3595695577249028), 'Network Administrator'),
#   (1076, np.float64(0.3510375568235907), 'Network Administrator'),
#   (1346, np.float64(0.3370511592122201), 'Network Administrator'),
#   (2142, np.float64(0.31821050983971266), 'Network Administrator')],
#  '13477922.pdf': [(1076,
#    np.float64(0.37456293731765855),
#    'Network Administrator'),
#   (2163, np.float64(0.3311964373679791), 'Network Administrator'),
#   (2137, np.float64(0.3284262964424062), 'Network Administrator'),
#   (2142, np.float64(0.31375963846398014), 'Network Administrator'),
#   (595, np.float64(0.3045012957095472), 'Network Administrator')],
#  '18752129.pdf': [(351, np.float64(0.1566408890920151), 'Machine Learning'),
#   (1270, np.float64(0.1540571486924372), 'Full Stack Developer'),
#   (1289, np.float64(0.09803114953209492), 'Full Stack Developer'),
#   (1770, np.float64(0.09662189361418279), 'Machine Learning'),
#   (876, np.float64(0.09476989926225281), 'Full Stack Developer')],
#  '91121135.pdf': [(1008,
#    np.float64(0.22847695754467257),
#    'JavaScript Developer'),
#   (1477, np.float64(0.22452018385441966), 'JavaScript Developer'),
#   (1692, np.float64(0.22081029710820912), 'JavaScript Developer'),
#   (510, np.float64(0.218081151370449), 'JavaScript Developer'),
#   (2224, np.float64(0.21322915450016286), 'JavaScript Developer')],
#  '15791766.pdf': [(2137,
#    np.float64(0.23531484777300482),
#    'Network Administrator'),
#   (580, np.float64(0.22385436363838634), 'Network Administrator'),
#   (1816, np.float64(0.19254023153605973), 'Network Administrator'),
#   (399, np.float64(0.18834932574345345), 'Network Administrator'),
#   (1009, np.float64(0.18825233349350157), 'Network Administrator')],
#  '17641670.pdf': [(580,
#    np.float64(0.38826210041917775),
#    'Network Administrator'),
#   (1816, np.float64(0.37844751542887983), 'Network Administrator'),
#   (1076, np.float64(0.3560745758620635), 'Network Administrator'),
#   (427, np.float64(0.3359144647659711), 'Network Administrator'),
#   (399, np.float64(0.3239317908980322), 'Network Administrator')],
#  '31111279.pdf': [(320,
#    np.float64(0.2603123388640765),
#    'Network Administrator'),
#   (1846, np.float64(0.21423107424693072), 'Database Administrator'),
#   (420, np.float64(0.1982309094137206), 'Database Administrator'),
#   (2244, np.float64(0.18288422539614224), 'Backend Developer'),
#   (893, np.float64(0.17804866458928864), 'Software Engineer')],
#  '91697974.pdf': [(2172,
#    np.float64(0.1980959847496093),
#    'Database Administrator'),
#   (1459, np.float64(0.17233575545260862), 'Database Administrator'),
#   (1348, np.float64(0.15693658044806644), 'Database Administrator'),
#   (1705, np.float64(0.1525330447607371), 'Database Administrator'),
#   (1205, np.float64(0.1461727061904218), 'Database Administrator')],
#  '79541391.pdf': [(1348,
#    np.float64(0.17813127877448245),
#    'Database Administrator'),
#   (625, np.float64(0.15161735057275333), 'Database Administrator'),
#   (1010, np.float64(0.15153381261016938), 'Database Administrator'),
#   (2069, np.float64(0.15118818582400162), 'Database Administrator'),
#   (1991, np.float64(0.150109918044123), 'Software Engineer')],
#  '25905275.pdf': [(2137,
#    np.float64(0.16866071662868362),
#    'Network Administrator'),
#   (515, np.float64(0.16824778405084437), 'Java Developer'),
#   (736, np.float64(0.16616679715949106), 'Full Stack Developer'),
#   (2228, np.float64(0.15868460889456915), 'Network Administrator'),
#   (626, np.float64(0.1563176535282923), 'Database Administrator')],
#  '91635250.pdf': [(2163,
#    np.float64(0.2588080433328451),
#    'Network Administrator'),
#   (1076, np.float64(0.2567118270685828), 'Network Administrator'),
#   (2137, np.float64(0.24176625646407307), 'Network Administrator'),
#   (580, np.float64(0.237305619454165), 'Network Administrator'),
#   (669, np.float64(0.22994790762884865), 'Network Administrator')],
#  '68460556.pdf': [(1413,
#    np.float64(0.12501770566550433),
#    'Database Administrator'),
#   (1938, np.float64(0.11455153928928526), 'Database Administrator'),
#   (533, np.float64(0.11445378294391244), 'Full Stack Developer'),
#   (1770, np.float64(0.10879869017215545), 'Machine Learning'),
#   (1540, np.float64(0.10777345442816665), 'Wordpress Developer')],
#  '20824105.pdf': [(659,
#    np.float64(0.3154828508080181),
#    'Network Administrator'),
#   (2142, np.float64(0.30509357359924383), 'Network Administrator'),
#   (973, np.float64(0.2937358177980464), 'Network Administrator'),
#   (1905, np.float64(0.27958735129667317), 'Network Administrator'),
#   (2217, np.float64(0.2649009243909251), 'Network Administrator')],
#  '10089434.pdf': [(580,
#    np.float64(0.2812519525714499),
#    'Network Administrator'),
#   (1818, np.float64(0.2812200778846285), 'Network Administrator'),
#   (812, np.float64(0.2668290607190926), 'Network Administrator'),
#   (1459, np.float64(0.2667471265091982), 'Database Administrator'),
#   (1076, np.float64(0.2666374036765792), 'Network Administrator')],
#  '24083609.pdf': [(1413,
#    np.float64(0.17709863209876456),
#    'Database Administrator'),
#   (1076, np.float64(0.1371432823594949), 'Network Administrator'),
#   (1655, np.float64(0.13359342577626943), 'Network Administrator'),
#   (530, np.float64(0.12659315486631115), 'Network Administrator'),
#   (580, np.float64(0.12270073934182266), 'Network Administrator')],
#  '28672970.pdf': [(1655,
#    np.float64(0.23218810712660481),
#    'Network Administrator'),
#   (580, np.float64(0.22551259430265444), 'Network Administrator'),
#   (1076, np.float64(0.20968010684406244), 'Network Administrator'),
#   (1271, np.float64(0.20130795761836115), 'Database Administrator'),
#   (399, np.float64(0.20117616278928566), 'Network Administrator')],
#  '12763627.pdf': [(2105, np.float64(0.2653659327316044), 'Backend Developer'),
#   (1876, np.float64(0.2025167142876026), 'Network Administrator'),
#   (1944, np.float64(0.19250227250166066), 'Network Administrator'),
#   (373, np.float64(0.18976701904355858), 'Software Engineer'),
#   (1429, np.float64(0.1890481240972905), 'Full Stack Developer')],
#  '92069209.pdf': [(1271,
#    np.float64(0.1706719679235233),
#    'Database Administrator'),
#   (364, np.float64(0.16995278481816595), 'Network Administrator'),
#   (1926, np.float64(0.16434207701473713), 'iOS Developer'),
#   (2048, np.float64(0.1636147788543654), 'Backend Developer'),
#   (2215, np.float64(0.16270588125731747), 'Network Administrator')],
#  '17111768.pdf': [(1681,
#    np.float64(0.203781488107263),
#    'Database Administrator'),
#   (1271, np.float64(0.1843223201501554), 'Database Administrator'),
#   (320, np.float64(0.1806401592070936), 'Network Administrator'),
#   (1495, np.float64(0.18027622219897158), 'Java Developer'),
#   (23, np.float64(0.17680801866816998), 'Database Administrator')],
#  '29975124.pdf': [(18,
#    np.float64(0.1909593621900001),
#    'Database Administrator'),
#   (625, np.float64(0.1866449087455922), 'Database Administrator'),
#   (1348, np.float64(0.17625140140990825), 'Database Administrator'),
#   (2205, np.float64(0.17051430718255536), 'Database Administrator'),
#   (970, np.float64(0.16779935237341712), 'Database Administrator')],
#  '52618188.pdf': [(1413,
#    np.float64(0.20235269039295128),
#    'Database Administrator'),
#   (1362, np.float64(0.18439005844102563), 'Network Administrator'),
#   (1991, np.float64(0.1836718706318299), 'Software Engineer'),
#   (234, np.float64(0.18043134945520237), 'Java Developer'),
#   (1586, np.float64(0.17646836931951512), 'JavaScript Developer')],
#  '18187364.pdf': [(1201,
#    np.float64(0.39623105199156244),
#    'Database Administrator'),
#   (18, np.float64(0.3947356748636494), 'Database Administrator'),
#   (625, np.float64(0.3616776525210216), 'Database Administrator'),
#   (1730, np.float64(0.3507262379538141), 'Database Administrator'),
#   (1348, np.float64(0.35019866549759665), 'Database Administrator')],
#  '90867631.pdf': [(580,
#    np.float64(0.3231959919443061),
#    'Network Administrator'),
#   (399, np.float64(0.26789560335881896), 'Network Administrator'),
#   (530, np.float64(0.2470348570136502), 'Network Administrator'),
#   (595, np.float64(0.24114435185449132), 'Network Administrator'),
#   (1283, np.float64(0.23528967187330094), 'Network Administrator')],
#  '70089206.pdf': [(625,
#    np.float64(0.19256782449757423),
#    'Database Administrator'),
#   (18, np.float64(0.18262556302218058), 'Database Administrator'),
#   (893, np.float64(0.18205143846517832), 'Software Engineer'),
#   (1991, np.float64(0.17895342282054638), 'Software Engineer'),
#   (1956, np.float64(0.17456303458803102), 'Node js developer')],
#  '23864648.pdf': [(580,
#    np.float64(0.2514249015644723),
#    'Network Administrator'),
#   (1850, np.float64(0.24035622082420413), 'Network Administrator'),
#   (1076, np.float64(0.21731000137495424), 'Network Administrator'),
#   (1655, np.float64(0.20340000058844662), 'Network Administrator'),
#   (399, np.float64(0.202516897029074), 'Network Administrator')],
#  '13836471.pdf': [(1385,
#    np.float64(0.3474791788688774),
#    'Network Administrator'),
#   (903, np.float64(0.3318979697088044), 'Network Administrator'),
#   (823, np.float64(0.2959208854186386), 'Network Administrator'),
#   (1362, np.float64(0.2945894877914801), 'Network Administrator'),
#   (580, np.float64(0.2705323825305027), 'Network Administrator')],
#  '30223363.pdf': [(2141,
#    np.float64(0.31249266527648295),
#    'Database Administrator'),
#   (641, np.float64(0.2585117203996602), 'Java Developer'),
#   (63, np.float64(0.2576725860033366), 'JavaScript Developer'),
#   (1880, np.float64(0.24550895761913735), 'Flutter Developer'),
#   (1991, np.float64(0.245088461974773), 'Software Engineer')],
#  '11580408.pdf': [(580,
#    np.float64(0.25067513272286235),
#    'Network Administrator'),
#   (1816, np.float64(0.22321145458517552), 'Network Administrator'),
#   (1009, np.float64(0.21232592773702122), 'Network Administrator'),
#   (903, np.float64(0.20923935194116916), 'Network Administrator'),
#   (1362, np.float64(0.20771436377525496), 'Network Administrator')],
#  '36856210.pdf': [(1459,
#    np.float64(0.1715563945763838),
#    'Database Administrator'),
#   (1655, np.float64(0.17135926686386702), 'Network Administrator'),
#   (1076, np.float64(0.1711219887336301), 'Network Administrator'),
#   (866, np.float64(0.16635964538159204), 'Software Engineer'),
#   (1348, np.float64(0.16220170501061484), 'Database Administrator')],
#  '48037995.pdf': [(980,
#    np.float64(0.19068521277842107),
#    'Database Administrator'),
#   (342, np.float64(0.13260157889121613), 'Full Stack Developer'),
#   (533, np.float64(0.11307920533672636), 'Full Stack Developer'),
#   (1060, np.float64(0.11026653502965367), 'DevOps Engineer'),
#   (326, np.float64(0.10802226451787017), 'Full Stack Developer')],
#  '19850482.pdf': [(1709, np.float64(0.28449041263534564), 'DevOps Engineer'),
#   (1514, np.float64(0.25664399065861576), 'Java Developer'),
#   (1076, np.float64(0.23465010551917373), 'Network Administrator'),
#   (1655, np.float64(0.21880905589936223), 'Network Administrator'),
#   (2163, np.float64(0.20796659658464306), 'Network Administrator')],
#  '17688766.pdf': [(580,
#    np.float64(0.25413950080075426),
#    'Network Administrator'),
#   (1076, np.float64(0.23294918773356138), 'Network Administrator'),
#   (903, np.float64(0.23283584843449864), 'Network Administrator'),
#   (399, np.float64(0.23133939508621668), 'Network Administrator'),
#   (823, np.float64(0.21606906431493675), 'Network Administrator')],
#  '20024870.pdf': [(1724, np.float64(0.11883017060062996), 'Machine Learning'),
#   (23, np.float64(0.0998194278192779), 'Database Administrator'),
#   (551, np.float64(0.09839187714272282), 'Database Administrator'),
#   (2028, np.float64(0.09819317206524968), 'Machine Learning'),
#   (1401, np.float64(0.09466541919966306), 'Java Developer')],
#  '18159866.pdf': [(1583, np.float64(0.20992119531348932), 'Java Developer'),
#   (481, np.float64(0.20716250613282305), 'Full Stack Developer'),
#   (1951, np.float64(0.2026616094262741), 'Software Engineer'),
#   (13, np.float64(0.2014067620158249), 'Software Engineer'),
#   (2228, np.float64(0.20078430881067957), 'Network Administrator')],
#  '11957080.pdf': [(580,
#    np.float64(0.2576758806182184),
#    'Network Administrator'),
#   (23, np.float64(0.22971367862311368), 'Database Administrator'),
#   (2137, np.float64(0.22940279653840262), 'Network Administrator'),
#   (1362, np.float64(0.22868387793441658), 'Network Administrator'),
#   (1655, np.float64(0.2282355099903081), 'Network Administrator')],
#  '20879311.pdf': [(903,
#    np.float64(0.2631228201611934),
#    'Network Administrator'),
#   (580, np.float64(0.24214315732477262), 'Network Administrator'),
#   (1362, np.float64(0.23498809009200008), 'Network Administrator'),
#   (399, np.float64(0.22874130954497526), 'Network Administrator'),
#   (1009, np.float64(0.22601638651440473), 'Network Administrator')],
#  '16186411.pdf': [(2105, np.float64(0.3528231367031369), 'Backend Developer'),
#   (373, np.float64(0.2527706623768063), 'Software Engineer'),
#   (2017, np.float64(0.249125603539802), 'Java Developer'),
#   (1944, np.float64(0.2471815471316831), 'Network Administrator'),
#   (1403, np.float64(0.22761413805840394), 'Java Developer')],
#  '51363762.pdf': [(1655,
#    np.float64(0.18775479071450812),
#    'Network Administrator'),
#   (1413, np.float64(0.17666845255262553), 'Database Administrator'),
#   (580, np.float64(0.15754523632343678), 'Network Administrator'),
#   (625, np.float64(0.15570678769815802), 'Database Administrator'),
#   (1991, np.float64(0.15277006843204083), 'Software Engineer')],
#  '10553553.pdf': [(903,
#    np.float64(0.27129801968518974),
#    'Network Administrator'),
#   (1362, np.float64(0.2515596239912961), 'Network Administrator'),
#   (1009, np.float64(0.24869086156202824), 'Network Administrator'),
#   (580, np.float64(0.23907016201773165), 'Network Administrator'),
#   (1204, np.float64(0.23478816637091376), 'Network Administrator')],
#  '37242217.pdf': [(1655,
#    np.float64(0.2896763699772888),
#    'Network Administrator'),
#   (580, np.float64(0.2656294722732622), 'Network Administrator'),
#   (399, np.float64(0.24679027412976814), 'Network Administrator'),
#   (530, np.float64(0.24193152300436116), 'Network Administrator'),
#   (1283, np.float64(0.21111841083341767), 'Network Administrator')],
#  '10265057.pdf': [(348, np.float64(0.17714646885680888), 'Java Developer'),
#   (2266, np.float64(0.17210609243960895), 'Machine Learning'),
#   (520, np.float64(0.15745567410350012), 'Machine Learning'),
#   (819, np.float64(0.15634673989756312), 'Machine Learning'),
#   (885, np.float64(0.15595331630615253), 'Machine Learning')],
#  '57002858.pdf': [(1362,
#    np.float64(0.25953596791221467),
#    'Network Administrator'),
#   (580, np.float64(0.22735744636777713), 'Network Administrator'),
#   (399, np.float64(0.22208748879928547), 'Network Administrator'),
#   (1009, np.float64(0.22140988908989923), 'Network Administrator'),
#   (903, np.float64(0.21683880907303346), 'Network Administrator')],
#  '10839851.pdf': [(580,
#    np.float64(0.18096930662062485),
#    'Network Administrator'),
#   (1459, np.float64(0.16574988499778948), 'Database Administrator'),
#   (399, np.float64(0.15927390582094786), 'Network Administrator'),
#   (1818, np.float64(0.14823146812686094), 'Network Administrator'),
#   (625, np.float64(0.14469942736058053), 'Database Administrator')],
#  '21780877.pdf': [(669,
#    np.float64(0.1853670031203062),
#    'Network Administrator'),
#   (1655, np.float64(0.1812926482753104), 'Network Administrator'),
#   (2137, np.float64(0.17904096118958437), 'Network Administrator'),
#   (2163, np.float64(0.17308160195517674), 'Network Administrator'),
#   (1076, np.float64(0.16843758012209675), 'Network Administrator')],
#  '18067556.pdf': [(885, np.float64(0.26506592589694383), 'Machine Learning'),
#   (2266, np.float64(0.23426671954971834), 'Machine Learning'),
#   (715, np.float64(0.23425219527106084), 'Database Administrator'),
#   (1724, np.float64(0.22934523250105587), 'Machine Learning'),
#   (547, np.float64(0.21542259329563865), 'Machine Learning')],
#  '20237244.pdf': [(2142,
#    np.float64(0.22140918339814086),
#    'Network Administrator'),
#   (1076, np.float64(0.21125463102837796), 'Network Administrator'),
#   (1346, np.float64(0.19395611042197575), 'Network Administrator'),
#   (1802, np.float64(0.18233676812574398), 'Network Administrator'),
#   (580, np.float64(0.18226397309731418), 'Network Administrator')],
#  '22776912.pdf': [(1655,
#    np.float64(0.18848194612701408),
#    'Network Administrator'),
#   (1583, np.float64(0.18797802511363065), 'Java Developer'),
#   (496, np.float64(0.17896738613839083), 'Machine Learning'),
#   (18, np.float64(0.17790001724262378), 'Database Administrator'),
#   (2028, np.float64(0.17681189980795775), 'Machine Learning')],
#  '14789139.pdf': [(320,
#    np.float64(0.2274916332719119),
#    'Network Administrator'),
#   (1681, np.float64(0.21618745185363783), 'Database Administrator'),
#   (1459, np.float64(0.20478077416222454), 'Database Administrator'),
#   (599, np.float64(0.18636173762046004), 'Software Engineer'),
#   (420, np.float64(0.18328336426261793), 'Database Administrator')],
#  '15651486.pdf': [(1027,
#    np.float64(0.3760708111584869),
#    'Network Administrator'),
#   (973, np.float64(0.37259958632037066), 'Network Administrator'),
#   (1802, np.float64(0.3558933783649335), 'Network Administrator'),
#   (1327, np.float64(0.3534409637433626), 'Network Administrator'),
#   (2142, np.float64(0.3229860337799343), 'Network Administrator')],
#  '27536013.pdf': [(320,
#    np.float64(0.18485529173612586),
#    'Network Administrator'),
#   (1348, np.float64(0.1807511807075382), 'Database Administrator'),
#   (1724, np.float64(0.17454653620297428), 'Machine Learning'),
#   (510, np.float64(0.17428335678333595), 'JavaScript Developer'),
#   (1583, np.float64(0.17416735068485956), 'Java Developer')],
#  '29075857.pdf': [(1647, np.float64(0.25266414534316267), 'Software Engineer'),
#   (607, np.float64(0.2513523532329054), 'Software Engineer'),
#   (1400, np.float64(0.23578592434312634), 'Software Engineer'),
#   (1600, np.float64(0.21495173660225747), 'Backend Developer'),
#   (145, np.float64(0.21279939089164282), 'Java Developer')],
#  '24020470.pdf': [(2137,
#    np.float64(0.20158286376117207),
#    'Network Administrator'),
#   (580, np.float64(0.17781025388563043), 'Network Administrator'),
#   (1362, np.float64(0.1732989628483107), 'Network Administrator'),
#   (399, np.float64(0.15794909879938535), 'Network Administrator'),
#   (1724, np.float64(0.15352628764855697), 'Machine Learning')],
#  '13405733.pdf': [(1724, np.float64(0.22524354250816336), 'Machine Learning'),
#   (336, np.float64(0.22189304346265892), 'Software Engineer'),
#   (641, np.float64(0.21376832941900967), 'Java Developer'),
#   (320, np.float64(0.21320182871862015), 'Network Administrator'),
#   (599, np.float64(0.21032388998805374), 'Software Engineer')],
#  '28897981.pdf': [(1459,
#    np.float64(0.14311549454885963),
#    'Database Administrator'),
#   (399, np.float64(0.14151482774245328), 'Network Administrator'),
#   (1655, np.float64(0.1357412677088751), 'Network Administrator'),
#   (1348, np.float64(0.13541338434360461), 'Database Administrator'),
#   (2177, np.float64(0.13533161160222035), 'Java Developer')]}

# %%
ct = 0
for resume, matches in results.items():
    print(f"\nResume: {resume}")
    for jd_id, score, title in matches:
        print(f"  JD ID: {jd_id} | Title: {title[:40]}... | Cosine Score: {score:.3f}")

    ct += 1
    if ct > 1:
        break
            
        # Optional: View contributing tokens
        # show_top_tokens_for_match(resume_texts[resume_names.index(resume)], jd_texts[jd_id], vectorizer)
# Out:
# Resume: 18176523.pdf
#   JD ID: 580 | Title: Network Administrator... | Cosine Score: 0.259
#   JD ID: 1655 | Title: Network Administrator... | Cosine Score: 0.232
#   JD ID: 399 | Title: Network Administrator... | Cosine Score: 0.227
#   JD ID: 1459 | Title: Database Administrator... | Cosine Score: 0.216
#   JD ID: 530 | Title: Network Administrator... | Cosine Score: 0.207
#
# Resume: 25857360.pdf
#   JD ID: 420 | Title: Database Administrator... | Cosine Score: 0.192
#   JD ID: 2033 | Title: Database Administrator... | Cosine Score: 0.160
#   JD ID: 534 | Title: Database Administrator... | Cosine Score: 0.140
#   JD ID: 102 | Title: Node js developer... | Cosine Score: 0.136
#   JD ID: 2169 | Title: Database Administrator... | Cosine Score: 0.127

# %%
# View full JD
# print_full_jd(jd_titles, jd_texts, jd_id=1027)

# %%
target_resume = '15651486.pdf'

# %%
# View contributing tokens
show_top_tokens_for_match(
    resume_texts[resume_names.index(target_resume)],
    jd_texts[903],
    vectorizer
)
# Out:
# Top Overlapping Tokens by TF-IDF Score:
# - cisco: 0.0871
# - windows: 0.0189
# - network: 0.0180
# - 2003: 0.0116
# - hardware: 0.0077
# - administration: 0.0070
# - connectivity: 0.0069
# - exchange: 0.0066
# - management: 0.0066
# - switches: 0.0063
# - printers: 0.0055
# - vpn: 0.0052
# - server: 0.0051
# - calls: 0.0048
# - routers: 0.0043
# - firewall: 0.0041
# - lan: 0.0041
# - setup: 0.0038
# - symantec: 0.0032
# - hp: 0.0028

# %%
res_df = pd.read_csv('gold_resumes.csv')
jd_df  = pd.read_csv('gold_jds.csv')

# %%
gold = {
    "R1": ["J1","J2","J3","J4"],
    "R2": ["J5","J6","J7","J8"],
    "R3": ["J9","J10","J11","J12"],
    "R4": ["J13","J14","J15","J16"],
    "R5": ["J17","J18","J19","J20"],
}

# %%
# Build resume names/texts from the gold CSV
resume_names = res_df['Resume_ID'].astype(str).tolist()
resume_texts = res_df['Resume_Text'].astype(str).tolist()

# Build JD titles/texts from the gold CSV
jd_titles = jd_df['Job_ID'].astype(str).tolist()
jd_texts  = jd_df['Job_Text'].astype(str).tolist()

# Now re-run your TF‑IDF matcher on the CSV data
results, vectorizer, _ = match_resumes_tfidf_cosine(
    resume_names,
    resume_texts,
    jd_titles,
    jd_texts,
    top_k=4
)

# %%
results
# Out:
# {'R1': [(0, np.float64(0.35224496704842806), 'J1'),
#   (2, np.float64(0.2070004260494528), 'J3'),
#   (1, np.float64(0.19206210052692727), 'J2'),
#   (4, np.float64(0.09375087652042687), 'J5')],
#  'R2': [(19, np.float64(0.16360361889851152), 'J20'),
#   (6, np.float64(0.14533547335639505), 'J7'),
#   (4, np.float64(0.12114093092163422), 'J5'),
#   (5, np.float64(0.11684457993776862), 'J6')],
#  'R3': [(8, np.float64(0.40563918407431593), 'J9'),
#   (15, np.float64(0.3781934027194118), 'J16'),
#   (9, np.float64(0.32804339092387474), 'J10'),
#   (10, np.float64(0.17833857579262372), 'J11')],
#  'R4': [(12, np.float64(0.18632821283191955), 'J13'),
#   (13, np.float64(0.14016774590035128), 'J14'),
#   (14, np.float64(0.12349738676805093), 'J15'),
#   (7, np.float64(0.08667120017807878), 'J8')],
#  'R5': [(16, np.float64(0.2519410943729674), 'J17'),
#   (17, np.float64(0.15326028993554586), 'J18'),
#   (18, np.float64(0.06646908233668641), 'J19'),
#   (4, np.float64(0.06568203249477786), 'J5')]}

# %%
def precision_at_k(recs, gold_set, k):
    return len(set(recs[:k]) & gold_set) / k

def recall_at_k(recs, gold_set, k):
    return len(set(recs[:k]) & gold_set) / len(gold_set)

def topk_accuracy(recs, gold_set, k):
    return 1.0 if set(recs[:k]) & gold_set else 0.0

def reciprocal_rank(recs, gold_set):
    for i, jid in enumerate(recs, start=1):
        if jid in gold_set:
            return 1.0 / i
    return 0.0

def dcg_at_k(rels, k):
    return sum(r / math.log2(i+1) for i, r in enumerate(rels[:k], start=1))

def ndcg_at_k(recs, gold_set, k):
    rels = [1 if jid in gold_set else 0 for jid in recs[:k]]
    dcg  = dcg_at_k(rels, k)
    ideal = [1] * min(len(gold_set), k)
    idcg = dcg_at_k(ideal, k)
    return dcg / idcg if idcg > 0 else 0.0

# %%
def evaluate(results, gold, k=4):
    P, R, T, RR, N = [], [], [], [], []
    for rid, ranked in results.items():
        if rid not in gold: continue
        gs   = set(gold[rid])
        recs = [title for _, _, title in ranked]
        P.append( precision_at_k(recs, gs, k) )
        R.append( recall_at_k(recs, gs, k)    )
        T.append( topk_accuracy(recs, gs, k)  )
        RR.append(reciprocal_rank(recs, gs)   )
        N.append( ndcg_at_k(recs, gs, k)      )
    return {
        f"Precision@{k}": sum(P)/len(P),
        f"Recall@{k}":    sum(R)/len(R),
        f"Top-{k} Acc.":  sum(T)/len(T),
        "MRR":            sum(RR)/len(RR),
        f"NDCG@{k}":      sum(N)/len(N),
    }

# %%
metrics = evaluate(results, gold, k=4)
for name, val in metrics.items():
    print(f"{name}: {val:.3f}")
# Out:
# Precision@4: 0.750
# Recall@4: 0.750
# Top-4 Acc.: 1.000
# MRR: 0.900
# NDCG@4: 0.772
